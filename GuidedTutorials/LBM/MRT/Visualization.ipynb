# %%
import numpy as np
import matplotlib.pyplot as plt
import yt
from yt.frontends.boxlib.data_structures import AMReXDataset

# %%
ts = yt.load('plt?????')
times = []
us = []
for ds in ts[:]:
    ad = ds.all_data()
    times.append(ds.current_time)
    us.append(ad.quantities.extrema('vely'))
ts = np.array(ts)
us = np.array(us)
# Out:
# yt : [INFO     ] 2022-06-06 09:24:07,705 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-06-06 09:24:07,706 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:07,707 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:07,708 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:07,961 Parameters: current_time              = 10.0
# yt : [INFO     ] 2022-06-06 09:24:07,962 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:07,962 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:07,963 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:08,184 Parameters: current_time              = 20.0
# yt : [INFO     ] 2022-06-06 09:24:08,184 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:08,185 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:08,186 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:08,404 Parameters: current_time              = 30.0
# yt : [INFO     ] 2022-06-06 09:24:08,405 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:08,405 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:08,407 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:08,674 Parameters: current_time              = 40.0
# yt : [INFO     ] 2022-06-06 09:24:08,675 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:08,676 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:08,677 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:08,899 Parameters: current_time              = 50.0
# yt : [INFO     ] 2022-06-06 09:24:08,900 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:08,901 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:08,902 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:09,118 Parameters: current_time              = 60.0
# yt : [INFO     ] 2022-06-06 09:24:09,119 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:09,120 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:09,121 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:09,336 Parameters: current_time              = 70.0
# yt : [INFO     ] 2022-06-06 09:24:09,337 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:09,337 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:09,339 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:09,556 Parameters: current_time              = 80.0
# yt : [INFO     ] 2022-06-06 09:24:09,557 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:09,558 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:09,559 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:09,794 Parameters: current_time              = 90.0
# yt : [INFO     ] 2022-06-06 09:24:09,795 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:09,796 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:09,797 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,027 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-06-06 09:24:10,028 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,029 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,030 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,245 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-06-06 09:24:10,246 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,247 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,248 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,281 Parameters: current_time              = 10.0
# yt : [INFO     ] 2022-06-06 09:24:10,282 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,282 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,283 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,315 Parameters: current_time              = 20.0
# yt : [INFO     ] 2022-06-06 09:24:10,316 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,317 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,318 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,348 Parameters: current_time              = 30.0
# yt : [INFO     ] 2022-06-06 09:24:10,349 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,350 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,351 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,382 Parameters: current_time              = 40.0
# yt : [INFO     ] 2022-06-06 09:24:10,383 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,384 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,385 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,417 Parameters: current_time              = 50.0
# yt : [INFO     ] 2022-06-06 09:24:10,418 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,419 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,420 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,450 Parameters: current_time              = 60.0
# yt : [INFO     ] 2022-06-06 09:24:10,451 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,452 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,453 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,483 Parameters: current_time              = 70.0
# yt : [INFO     ] 2022-06-06 09:24:10,484 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,485 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,486 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,517 Parameters: current_time              = 80.0
# yt : [INFO     ] 2022-06-06 09:24:10,518 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,518 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,519 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,550 Parameters: current_time              = 90.0
# yt : [INFO     ] 2022-06-06 09:24:10,550 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,551 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,552 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-06 09:24:10,583 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-06-06 09:24:10,584 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-06 09:24:10,585 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-06 09:24:10,586 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
yt.LinePlot(ds, 'vely', (0,0,0), (1,0,0), 16)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
fig, ax = plt.subplots(figsize=(8,6))
plt.plot(times,np.log(us[:,1]), '.-')
plt.show()

# %%
np.polyfit(times,np.log(us[:,1]),1)
# Out:
# array([-0.02067913, -6.91087888])

# %%
# data input manually from a few runs with different taus
nx = 16
k = 2*np.pi/nx
tau = [ 1.0, 0.9, 0.8, 0.7, 0.6 ]
ls = [ -0.02570095, -0.02067913, -0.0155872, -0.01044244, -5.26044347e-03 ] 
nu = 1./3.*(np.array(tau)-0.5)
lp = -nu*k**2

# %%
plt.plot(nu, lp, 'k:', label="Theory")
plt.plot(nu, ls, 'o', label='LBMeX')
plt.xlabel(r'$\nu=c_s^2(\tau-\frac{h}{2})$', size=16)
plt.ylabel(r'$\lambda=-\nu k^2$', size=16)
plt.title("Viscous decay rate of sinusoidal shear waves", size=18)
plt.legend(fontsize=16)
plt.show()
