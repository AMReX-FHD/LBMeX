# %%
import numpy as np
import matplotlib.pyplot as plt
import yt

# %% [markdown]
# # Fluctuating Lattice Boltzmann in AMReX

# %% [markdown]
# ## Lattice Boltzmann equation
#
# \begin{align}
# f_i(\vec{x}+h\vec{c}_i,t+h) = f_i^*(\vec{x},t) &\\
# f_i^*(\vec{x},t) &= f_i^{eq} + \left(1-\frac{h}{\tau}\right)\left( f_i - f_i^{eq}\right)
# \end{align}
#
# ### Equilibrium distribution
#
# \begin{equation}
# f_i^{eq} = w_i \rho \left( 1 + \frac{\vec{u}\cdot\vec{c}_i}{c_s^2} + \frac{\vec{u}\vec{u}\ \colon \left( \vec{c}_i\vec{c}_i - c_s^2 \mathsf{1} \right)}{2c_s^4} \right)
# \end{equation}
#
# ### Hydrodynamic moments
#
# \begin{align}
# \rho &= \sum_i f_i \\
# \rho \vec{u} &= \sum_i f_i \vec{c}_i \\
# \Pi &= \sum_i f_i \vec{c}_i\vec{c}_i & \Pi^{eq} &= \rho c_s \mathsf{1} + \rho\vec{u}\vec{u}
# \end{align}

# %% [markdown]
# ## MRT Formulation
#
# \begin{equation}
# \begin{split}
# \mathbf{f}^*(\vec{x},t) &= \mathbf{f}^{eq}(\vec{x},t) + \left(\mathsf{1} - \mathsf{\Lambda} \right) \left( \mathbf{f} - \mathbf{f}^{eq}\right) \\
# &= \mathbf{f}^{eq}(\vec{x},t) + \mathsf{M}^{-1}\mathsf{\Gamma}\mathsf{M}\left( \mathbf{f} - \mathbf{f}^{eq}\right) \\
# & = \mathsf{M}^{-1} \left[ \mathbf{m} + \mathsf{\Gamma} \left( \mathbf{m} - \mathbf{m}^{eq} \right) \right]
# \end{split}
# \end{equation}
#
# \begin{align}
# m_k &= \sum_i f_i e_{ki} \\
# f_i &= \sum_k \frac{w_i}{b_k} m_k e_{ki} \\
# b_k &= \sum_i w_i e_{ki}^2 \\
# \end{align}
#
# \begin{equation}
# m_k^* = m_k^{eq} + \gamma_k \left( m_k - m_k^{eq} \right)
# \end{equation}
#
# Allows for independent relaxation of bulk and shear modes, and odd and even kinetic moments.

# %% [markdown]
# ### Collision process generates viscous relaxation
#
# ##### From Chapman-Enskog expansion
#
# Term that enters divergence of momentum flux:
#
# \begin{equation}
# -Q = \Pi - \Pi^{eq} + \frac{1}{2} \left( \Pi^* - \Pi \right)
# = \frac{1}{2} \left( \Pi^{*,neq} + \Pi^{neq} \right)
# \end{equation}
#
# \begin{align}
# %\Pi^*_{\alpha\beta} - \Pi_{\alpha\beta} &= \rho c_s^2 \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right) \\
# \Pi^*_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} &= \gamma \left( \Pi_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} \right) \\
# \Pi_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} &= - \frac{\rho c_s^2}{1-\gamma} \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right)
# \end{align}
#
# So the Newtonian viscous stress is recovered in the form
#
# \begin{equation}
# Q = \frac{\rho c_s^2}{2} \frac{1+\gamma}{1-\gamma} \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right)
# \end{equation}
#
# ##### Viscosity in LB
#
# \begin{align}
# \eta &= \frac{\rho c_s^2}{2} \frac{1+\gamma}{1-\gamma} \\
# \zeta &=  \frac{\rho c_s^2}{d} \frac{1+\gamma}{1-\gamma}
# \end{align}

# %% [markdown]
# ## Viscous decay of sinusoidal shear waves

# %%
ts = yt.load('shear_wave/plt?????');
times = []
us = []
for ds in ts[:]:
    ad = ds.all_data()
    times.append(ds.current_time)
    us.append(ad.quantities.extrema('uy'))
ts = np.array(ts)
us = np.array(us)
# Out:
# yt : [INFO     ] 2022-06-15 11:54:07,096 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-06-15 11:54:07,097 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:07,098 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:07,099 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:07,368 Parameters: current_time              = 10.0
# yt : [INFO     ] 2022-06-15 11:54:07,368 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:07,369 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:07,370 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:07,592 Parameters: current_time              = 20.0
# yt : [INFO     ] 2022-06-15 11:54:07,593 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:07,594 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:07,595 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:07,818 Parameters: current_time              = 30.0
# yt : [INFO     ] 2022-06-15 11:54:07,818 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:07,819 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:07,820 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:08,091 Parameters: current_time              = 40.0
# yt : [INFO     ] 2022-06-15 11:54:08,091 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:08,092 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:08,094 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:08,314 Parameters: current_time              = 50.0
# yt : [INFO     ] 2022-06-15 11:54:08,314 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:08,315 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:08,316 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:08,534 Parameters: current_time              = 60.0
# yt : [INFO     ] 2022-06-15 11:54:08,535 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:08,536 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:08,537 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:08,769 Parameters: current_time              = 70.0
# yt : [INFO     ] 2022-06-15 11:54:08,770 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:08,771 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:08,772 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,011 Parameters: current_time              = 80.0
# yt : [INFO     ] 2022-06-15 11:54:09,012 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,013 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,014 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,265 Parameters: current_time              = 90.0
# yt : [INFO     ] 2022-06-15 11:54:09,266 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,266 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,268 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,502 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-06-15 11:54:09,503 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,504 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,505 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,721 Parameters: current_time              = 0.0
# yt : [INFO     ] 2022-06-15 11:54:09,722 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,723 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,724 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,757 Parameters: current_time              = 10.0
# yt : [INFO     ] 2022-06-15 11:54:09,758 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,759 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,760 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,791 Parameters: current_time              = 20.0
# yt : [INFO     ] 2022-06-15 11:54:09,791 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,792 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,793 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,823 Parameters: current_time              = 30.0
# yt : [INFO     ] 2022-06-15 11:54:09,824 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,825 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,826 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,857 Parameters: current_time              = 40.0
# yt : [INFO     ] 2022-06-15 11:54:09,858 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,859 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,860 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,891 Parameters: current_time              = 50.0
# yt : [INFO     ] 2022-06-15 11:54:09,892 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,893 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,893 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,923 Parameters: current_time              = 60.0
# yt : [INFO     ] 2022-06-15 11:54:09,924 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,925 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,925 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,957 Parameters: current_time              = 70.0
# yt : [INFO     ] 2022-06-15 11:54:09,958 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,959 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,959 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:09,991 Parameters: current_time              = 80.0
# yt : [INFO     ] 2022-06-15 11:54:09,992 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:09,993 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:09,994 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:10,024 Parameters: current_time              = 90.0
# yt : [INFO     ] 2022-06-15 11:54:10,025 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:10,026 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:10,027 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2022-06-15 11:54:10,057 Parameters: current_time              = 100.0
# yt : [INFO     ] 2022-06-15 11:54:10,058 Parameters: domain_dimensions         = [16 16 16]
# yt : [INFO     ] 2022-06-15 11:54:10,059 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2022-06-15 11:54:10,060 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
yt.LinePlot(ds, 'uy', (0,0,0), (1,0,0), 16)
# Out:
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
m, b = np.polyfit(times,np.log(us[:,1]),1)

plt.plot(times,np.log(us[:,1]), '.', label=r"LBMeX")
plt.plot(times,m*np.array(times)+b, 'k:', label="linear fit")
plt.ylabel(r"$\log\left(\max\ u_y\right)$")
plt.xlabel("timesteps")
plt.legend()
plt.show()

# %%
# data input manually from a few runs with different taus
tau = [ 1.0, 0.9, 0.8, 0.7, 0.6 ]
ls = [ -0.02570095, -0.02067913, -0.0155872, -0.01044244, -5.26044347e-03 ] 

nx = 16
k = 2*np.pi/nx
nu = 1./3.*(np.array(tau)-0.5)
lp = -nu*k**2

# %%
plt.plot(nu, lp, 'k:', label="Theory")
plt.plot(nu, ls, 'o', label='LBMeX')
plt.xlabel(r'$\nu=c_s^2(\tau-\frac{h}{2})$', size=16)
plt.ylabel(r'$\lambda=-\nu k^2$', size=16)
plt.title("Viscous decay rate of sinusoidal shear waves", size=18)
plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# ## Introducing fluctuations

# %% [markdown]
# ### Fluctuations are added to non-conserved moments during collisions
#
# \begin{equation}
# m_k^{neq,*} = \gamma m_k^{neq} + r_k
# \end{equation}
#
# To maintain detailed balance:
#
# \begin{equation}
# \left\langle r_k^2 \right\rangle = \frac{\rho k_BT}{c_s^2} \left(1-\gamma^2\right) b_k
# \end{equation}

# %% [markdown]
# ### Lattice level fluctuations are _not_ hydrodynamic fluctuations
#
# ##### From Chapman-Enskog expansion
#
# \begin{equation}
# -Q = \Pi - \Pi^{eq} + \frac{1}{2} \left( \Pi^* - \Pi \right)
# = \frac{1}{2} \left( \Pi^{*,neq} + \Pi^{neq} \right)
# \end{equation}
#
# \begin{align}
# %\Pi^*_{\alpha\beta} - \Pi_{\alpha\beta} &= \rho c_s^2 \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right) \\
# \Pi^*_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} &= \gamma \left( \Pi_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} \right) + R\\
# \Pi_{\alpha\beta} - \Pi^{eq}_{\alpha\beta} &= - \frac{\rho c_s^2}{1-\gamma} \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right) + \frac{1}{1-\gamma} R
# \end{align}
#
# \begin{equation}
# Q = \frac{\rho c_s^2}{2} \frac{1+\gamma}{1-\gamma} \left(\partial_\alpha u_\beta + \partial_\beta u_\alpha \right) + \frac{1}{1-\gamma} R
# \end{equation}
#
# \begin{equation}
# \left\langle Q^2 \right\rangle = \frac{\rho k_BT}{c_s^2} \tilde{b}_k \frac{1-\gamma^2}{(1-\gamma)^2} \sim 2 \eta k_B T \frac{\tilde{b}_k}{c_s^4}
# \end{equation}

# %% [markdown]
# ### "Measuring" the fluctuating stress in LB
#
# Chapman-Enskog says measure this:
# \begin{equation}
# Q = \frac{1}{2} \left( \Pi^{neq,*} + \Pi^{neq} \right) = \frac{1}{2} (1+\gamma) \Pi^{neq} + \frac{1}{2}R
# \end{equation}
#
# However, numerical observations indicate that, when measured instantaneously, the variance of $\Pi^{neq}$ and $\Pi^{neq,*}$ is the _lattice level_ variance (see $\left\langle r_k^2 \right\rangle$ above). Therefore
#
# \begin{equation}
# %\left\langle Q^2 \right\rangle = \frac{1}{2} \left[ (1+\gamma)^2 + 1 \right ]
# \end{equation}
# _calculation SNAFU_
# \begin{equation}
# %\left\langle Q^2 \right\rangle = \frac{1}{2} \frac{\rho k_BT}{c_s^2}(1-\gamma^2) \tilde{b}_k
# \end{equation}
#
# it deviates from the _hydrodynamic_ correlations by a factor $\frac{1-\gamma}{2}$.
#
# The correct hydrodynamic correlations are obtained by multiplying the measured fluctuations by $\frac{2}{1+\gamma}$.
#
# Confirmed numerically:

# %%
ts = yt.load('structure_factor/plt_SF_mag?????????');
ds = ts[-1];
print(ds.current_time)
# Out:
# yt : [INFO     ] 2022-06-15 11:54:10,693 Parameters: current_time              = 1000.0
# yt : [INFO     ] 2022-06-15 11:54:10,694 Parameters: domain_dimensions         = [64 64 64]
# yt : [INFO     ] 2022-06-15 11:54:10,696 Parameters: domain_left_edge          = [-201.06192983 -201.06192983 -201.06192983]
# yt : [INFO     ] 2022-06-15 11:54:10,697 Parameters: domain_right_edge         = [201.06192983 201.06192983 201.06192983]
# 1000.0 code_time

# %%
from mpl_toolkits.axes_grid1 import AxesGrid

fig = plt.figure()

# See http://matplotlib.org/mpl_toolkits/axes_grid/api/axes_grid_api.html
# These choices of keyword arguments produce a four panel plot that includes
# four narrow colorbars, one for each plot.  Axes labels are only drawn on the
# bottom left hand plot to avoid repeating information and make the plot less
# cluttered.
grid = AxesGrid(
    fig,
    (0.075, 0.075, 0.85, 0.85),
    nrows_ncols=(3, 3),
    axes_pad=1.0,
    label_mode="1",
    share_all=True,
    cbar_location="right",
    cbar_mode="each",
    cbar_size="3%",
    cbar_pad="0%",
)

fields = [
    ('boxlib', 'struct_fact_ux_ux'),
    ('boxlib', 'struct_fact_ux_uy'),
    ('boxlib', 'struct_fact_ux_uz'),
    ('boxlib', 'struct_fact_ux_uy'),
    ('boxlib', 'struct_fact_uy_uy'),
    ('boxlib', 'struct_fact_uy_uz'),
    ('boxlib', 'struct_fact_ux_uz'),
    ('boxlib', 'struct_fact_uy_uz'),
    ('boxlib', 'struct_fact_uz_uz'),
]
#fields = ds.field_list

# Create the plot.  Since SlicePlot accepts a list of fields, we need only
# do this once.
p = yt.SlicePlot(ds, 2, fields)

# Velocity is going to be both positive and negative, so let's make these
# slices use a linear colorbar scale
#p.set_log(("gas", "velocity_x"), False)
#p.set_log(("gas", "velocity_y"), False)
#p.zoom(2)

# For each plotted field, force the SlicePlot to redraw itself onto the AxesGrid
# axes.
for i, field in enumerate(fields):
    plot = p.plots[field]
    plot.figure = fig
    plot.axes = grid[i].axes
    plot.cax = grid.cbar_axes[i]
# Out:
# yt : [INFO     ] 2022-06-15 11:54:11,106 xlim = -201.061930 201.061930
# yt : [INFO     ] 2022-06-15 11:54:11,106 ylim = -201.061930 201.061930
# yt : [INFO     ] 2022-06-15 11:54:11,107 xlim = -201.061930 201.061930
# yt : [INFO     ] 2022-06-15 11:54:11,107 ylim = -201.061930 201.061930
# yt : [INFO     ] 2022-06-15 11:54:11,109 Making a fixed resolution buffer of (('boxlib', 'struct_fact_ux_ux')) 800 by 800
# yt : [INFO     ] 2022-06-15 11:54:11,122 Making a fixed resolution buffer of (('boxlib', 'struct_fact_ux_uy')) 800 by 800
# yt : [INFO     ] 2022-06-15 11:54:11,129 Making a fixed resolution buffer of (('boxlib', 'struct_fact_ux_uz')) 800 by 800
# yt : [INFO     ] 2022-06-15 11:54:11,138 Making a fixed resolution buffer of (('boxlib', 'struct_fact_uy_uy')) 800 by 800
# yt : [INFO     ] 2022-06-15 11:54:11,145 Making a fixed resolution buffer of (('boxlib', 'struct_fact_uy_uz')) 800 by 800
# yt : [INFO     ] 2022-06-15 11:54:11,153 Making a fixed resolution buffer of (('boxlib', 'struct_fact_uz_uz')) 800 by 800
# yt : [WARNING  ] 2022-06-15 11:54:11,174 Plotting ('boxlib', 'struct_fact_uy_uz'): Both positive and negative values. Min = 0.0 dimensionless, Max = 0.5165493495006892 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,174 Switching to symlog colorbar scaling.
# yt : [WARNING  ] 2022-06-15 11:54:11,258 Plotting ('boxlib', 'struct_fact_uy_uy'): Both positive and negative values. Min = 0.0 dimensionless, Max = 2.2740970106546765 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,259 Switching to symlog colorbar scaling.
# yt : [WARNING  ] 2022-06-15 11:54:11,344 Plotting ('boxlib', 'struct_fact_ux_uy'): Both positive and negative values. Min = 0.0 dimensionless, Max = 0.2849379703656915 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,344 Switching to symlog colorbar scaling.
# yt : [WARNING  ] 2022-06-15 11:54:11,434 Plotting ('boxlib', 'struct_fact_uz_uz'): Both positive and negative values. Min = 0.0 dimensionless, Max = 2.043316938514107 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,435 Switching to symlog colorbar scaling.
# yt : [WARNING  ] 2022-06-15 11:54:11,591 Plotting ('boxlib', 'struct_fact_ux_uz'): Both positive and negative values. Min = 0.0 dimensionless, Max = 0.6660564330128188 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,591 Switching to symlog colorbar scaling.
# yt : [WARNING  ] 2022-06-15 11:54:11,672 Plotting ('boxlib', 'struct_fact_ux_ux'): Both positive and negative values. Min = 0.0 dimensionless, Max = 2.837109783264428 dimensionless.
# yt : [WARNING  ] 2022-06-15 11:54:11,672 Switching to symlog colorbar scaling.

# %%
# Finally, redraw the plot on the AxesGrid axes.
p._setup_plots()

plt.show()

# %%
nu = 1/12
corr_names = [ 'rho_rho', 'ux_ux', 'uy_uy', 'uz_uz', 'pxx_pxx', 'pyy_pyy', 'pzz_pzz', 'pxy_pxy', 'pxz_pxz', 'pyz_pyz' ]
corr_expected = [ 3.0, 1.0, 1.0, 4*nu, 4*nu, 4*nu, 2*nu, 2*nu, 2*nu ]
cs = []
for name in corr_names:
    cs.append(ds.r[:,:,:].mean('struct_fact_'+name).value)
cs = np.array(cs)
pos = np.arange(len(corr_names))

# %%
plt.bar(pos,cs)
plt.xticks(pos,map(lambda n: n.split('_')[0], corr_names))
for c in corr_expected:
    plt.axhline(y=c, c='k', ls=':')
plt.ylabel(r'$\langle m m^* \rangle$ [$k_B T$]', size=16)
plt.xlabel('Moment $m$', size=16)
plt.show()

# %% [markdown]
# This remains a bit unsatisfying, so another test is to look at time correlations (underway).
#
# \begin{equation}
# \left\langle \Pi(t)\Pi(t+t') \right\rangle
# \end{equation}

# %% [markdown]
# ## Next (Giant) Fluctuations in Binary/Ternary Mixtures
